# %%
import json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime as dt 
from elasticsearch import Elasticsearch
import tweepy
from config import *

es = Elasticsearch()


class TweetStreamListener(StreamListener):

    def on_data(self, data):

        # decode json
        dict_data = json.loads(data)
       
    
    
    
        coord = dict_data["coordinates"]
        if coord is not None:
            coord = dict_data["coordinates"]
            lan = dict_data["coordinates"][0]
            lat = dict_data["coordinates"][1]
        else:
            coord = "None"
    
    
        tweet_date = dict_data['created_at']
        username = dict_data['user']['name']
        account_creation_date = dict_data['created_at']
        user_description = dict_data['user']['description']
        user_url = dict_data['user']['url']
        verified_status = dict_data['user']['verified']
        source = dict_data['source']
        friends_count = dict_data['user']['friends_count']
        followers_count = dict_data['user']['followers_count']
        retweeted_count = dict_data['retweet_count']
        favorite_count = dict_data['favorite_count']
        hashtags = dict_data['entities']['hashtags']
        location = dict_data["user"]["location"]
        
        tweet_full_text = dict_data['text']
        
        # preparando os dados para o elasticsearch
        doc = {
            '@timestamp': dt.now(),
            'data_tweet': tweet_date,
            'nome': str(username),
            'account_creation_date': str(account_creation_date),
            'descricao_usuario': str(user_description),
            'url_usuario': str(user_url),
            'user_verificado': bool(verified_status),
            'source': str(source),
            'friends_count': int(friends_count),
            'seguidores': int(followers_count),
            'retweeted_count': int(retweeted_count),
            'favorite_count': int(favorite_count),
            'hashtags': hashtags,
            'location': str(location),
            'tweet_full_text': str(tweet_full_text),
            'word_list': str(tweet_full_text).split(' '),
            "coordinates": coord
        }
        
        
        
        # add text and sentiment info to elasticsearch
        es.index(index="dados_api", body=doc)
#                  
                 
#                  body={dict_data["user"]["screen_name"],
#                           dict_data["timestamp_ms"],
#                           dict_data["created_at"], # unfortunately this gets stored as a string
#                           dict_data["user"]["location"], # user location
#                           dict_data["text"])
        
        for d in dict_data.items():
            print(d)
            
        print('')              
        return True

    # on failure
    def on_error(self, status):
        print(status)

if __name__ == '__main__':

    # create instance of the tweepy tweet stream listener
    listener = TweetStreamListener()

    # set twitter keys/tokens
    consumer_key="lOjJGrF8QybsC1eBNEqYCgKjW"
    consumer_secret="W0uvZLOwZANbUZwbpHHfrmCTv4nJ6G0CjBgoGNs8QwAbyKaABt"
    access_token="1396467357724315650-N12JYtGuTFnBqc3zJ2Jkn2mDYh1J3s"
    access_token_secret="94VIdoc9Vp9EyuIDUUQSbMlrANuRYjf2DbNWKOBf6Bjen"
    
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    # create instance of the tweepy stream
    stream = Stream(auth, listener)
    
    stream.sample(languages=['pt'])

    # search twitter for "congress" keyword
    stream.filter(track=["messi", "psg", "barcelona"])
# Out:
# ('created_at', 'Sun Aug 08 01:32:37 +0000 2021')
# ('id', 1424181723949146115)
# ('id_str', '1424181723949146115')
# ('text', 'essa semana inteira comi porcaria, desse jeito vou recuperar tudo o que emagreci com covid')
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', False)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 69144795, 'id_str': '69144795', 'name': 'thai na', 'screen_name': 'tthaaaina', 'location': '@rodscrf ♡', 'url': 'https://www.instagram.com/thainzw', 'description': 'conteúdo entediante', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1243, 'friends_count': 493, 'listed_count': 20, 'favourites_count': 49940, 'statuses_count': 135685, 'created_at': 'Thu Aug 27 00:21:30 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'B8B1B8', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_tile': True, 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F6F6F6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1401503297157074946/5EXrrzmC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1401503297157074946/5EXrrzmC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/69144795/1625402516', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386357663')
#
# ('created_at', 'Sun Aug 08 01:32:37 +0000 2021')
# ('id', 1424181723944787976)
# ('id_str', '1424181723944787976')
# ('text', '@bfr_Mtss aiai')
# ('display_text_range', [10, 14])
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', False)
# ('in_reply_to_status_id', 1424180665600417795)
# ('in_reply_to_status_id_str', '1424180665600417795')
# ('in_reply_to_user_id', 1009943866169012224)
# ('in_reply_to_user_id_str', '1009943866169012224')
# ('in_reply_to_screen_name', 'bfr_Mtss')
# ('user', {'id': 2830381838, 'id_str': '2830381838', 'name': 'eduarda 🦅🇧🇷', 'screen_name': 'wftslytherin', 'location': 'asgard ⚔ sonserina • BA ✈ 022', 'url': 'https://instagram.com/wtfslytherin?utm_medium=copy_link', 'description': 'nas boas eu te sigo, nas más eu te amo @corinthians II @neymarjr 💍', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1321, 'friends_count': 1146, 'listed_count': 0, 'favourites_count': 49734, 'statuses_count': 60309, 'created_at': 'Wed Sep 24 19:41:30 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '9266CC', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': 'DD2E44', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1424177029948321796/kjQZiq_z_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1424177029948321796/kjQZiq_z_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2830381838/1626628236', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'bfr_Mtss', 'name': 'Emitê 🇨🇷', 'id': 1009943866169012224, 'id_str': '1009943866169012224', 'indices': [0, 9]}], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386357662')
#
# ('created_at', 'Sun Aug 08 01:32:37 +0000 2021')
# ('id', 1424181723953344517)
# ('id_str', '1424181723953344517')
# ('text', '@manfitbrhot @AlexandreMello2 Delícia esses calções')
# ('display_text_range', [30, 51])
# ('source', '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>')
# ('truncated', False)
# ('in_reply_to_status_id', 1384900229724528640)
# ('in_reply_to_status_id_str', '1384900229724528640')
# ('in_reply_to_user_id', 1228061333712756745)
# ('in_reply_to_user_id_str', '1228061333712756745')
# ('in_reply_to_screen_name', 'manfitbrhot')
# ('user', {'id': 1339307200246853636, 'id_str': '1339307200246853636', 'name': '🅴🆅🅰🅽🅳🅴🆁💦6️⃣5️⃣K 🇧🇷🅳🆄🅼🅿 💦MILK 🔞', 'screen_name': 'Evander691', 'location': 'Novo Hamburgo-RS', 'url': 'http://www.xvideos.com/profiles/evander68', 'description': '🅾🅽🅻🆈 🆁🅴🅰🅻 🆂🅴🆇  🔞CUM🅳🆄🅼🅿 💦         \n 🅵🆄🅽🏳️\u200d🌈🅿🅾🆁🅽 🎵Ǥ𝒶Ⓨ🏳️\u200d🌈 ⓜⓘⓛⓚ 𝕔ᒪⓤⓑ💦🔞🆆🅴🅻🅲🅾🅼🅴🔞\n♫ 𝐅𝐞𝐥𝐥𝐨𝐰 𝐌𝐞 ♫ 👹', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 65978, 'friends_count': 988, 'listed_count': 147, 'favourites_count': 5615, 'statuses_count': 2894, 'created_at': 'Wed Dec 16 20:31:59 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1417427977332314140/8Q1I-NIN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1417427977332314140/8Q1I-NIN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1339307200246853636/1626777355', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'manfitbrhot', 'name': 'Man.fit.br', 'id': 1228061333712756745, 'id_str': '1228061333712756745', 'indices': [0, 12]}, {'screen_name': 'AlexandreMello2', 'name': 'Alexandre Mello', 'id': 1310874703662387202, 'id_str': '1310874703662387202', 'indices': [13, 29]}], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386357664')
#
# ('created_at', 'Sun Aug 08 01:32:37 +0000 2021')
# ('id', 1424181723957444611)
# ('id_str', '1424181723957444611')
# ('text', 'Oq eu quis dizer com isso: nada po, apenas mostrando que essa lógica n tem sentido')
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', False)
# ('in_reply_to_status_id', 1424181254535192583)
# ('in_reply_to_status_id_str', '1424181254535192583')
# ('in_reply_to_user_id', 1341429811659612161)
# ('in_reply_to_user_id_str', '1341429811659612161')
# ('in_reply_to_screen_name', 'MdsLakers')
# ('user', {'id': 1341429811659612161, 'id_str': '1341429811659612161', 'name': 'Only a Lakers Fan🌈', 'screen_name': 'MdsLakers', 'location': 'Staples Center', 'url': None, 'description': '@LakerCastBR Hoster, (ele/dele) \n.\nIcon made by @shapeedits \n.\n #LakeShow  #RootedInLA\n.\n#LoveIsLove', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2213, 'friends_count': 974, 'listed_count': 16, 'favourites_count': 5924, 'statuses_count': 21711, 'created_at': 'Tue Dec 22 17:06:17 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1418742393071751169/UROLJeOk_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1418742393071751169/UROLJeOk_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1341429811659612161/1624894904', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386357665')
# ('created_at', 'Sun Aug 08 01:32:37 +0000 2021')
# ('id', 1424181723957547014)
# ('id_str', '1424181723957547014')
# ('text', '@golden_willows Aprende https://t.co/lGfLgmiXUh')
# ('display_text_range', [16, 23])
# ('source', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>')
# ('truncated', False)
# ('in_reply_to_status_id', 1424181577928560643)
# ('in_reply_to_status_id_str', '1424181577928560643')
# ('in_reply_to_user_id', 1344492804957995008)
# ('in_reply_to_user_id_str', '1344492804957995008')
# ('in_reply_to_screen_name', 'golden_willows')
# ('user', {'id': 1194022727641960450, 'id_str': '1194022727641960450', 'name': 'yeli 🇵🇷🏅', 'screen_name': 'swiftiewidow', 'location': '🇵🇷; TN x1. ┆NO larries', 'url': None, 'description': 'natasha romanoff gf. ⴵ', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1198, 'friends_count': 1222, 'listed_count': 8, 'favourites_count': 6170, 'statuses_count': 4460, 'created_at': 'Mon Nov 11 22:43:04 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1421688120072974336/ap13iws0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1421688120072974336/ap13iws0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1194022727641960450/1627791593', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'golden_willows', 'name': 'Nicol✨🇵🇷', 'id': 1344492804957995008, 'id_str': '1344492804957995008', 'indices': [0, 15]}], 'symbols': [], 'media': [{'id': 1424181717103960067, 'id_str': '1424181717103960067', 'indices': [24, 47], 'media_url': 'http://pbs.twimg.com/media/E8O1ud-WYAMuT-a.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E8O1ud-WYAMuT-a.jpg', 'url': 'https://t.co/lGfLgmiXUh', 'display_url': 'pic.twitter.com/lGfLgmiXUh', 'expanded_url': 'https://twitter.com/swiftiewidow/status/1424181723957547014/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 314, 'h': 680, 'resize': 'fit'}, 'large': {'w': 828, 'h': 1792, 'resize': 'fit'}, 'medium': {'w': 554, 'h': 1200, 'resize': 'fit'}}}]})
# ('extended_entities', {'media': [{'id': 1424181717103960067, 'id_str': '1424181717103960067', 'indices': [24, 47], 'media_url': 'http://pbs.twimg.com/media/E8O1ud-WYAMuT-a.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E8O1ud-WYAMuT-a.jpg', 'url': 'https://t.co/lGfLgmiXUh', 'display_url': 'pic.twitter.com/lGfLgmiXUh', 'expanded_url': 'https://twitter.com/swiftiewidow/status/1424181723957547014/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 314, 'h': 680, 'resize': 'fit'}, 'large': {'w': 828, 'h': 1792, 'resize': 'fit'}, 'medium': {'w': 554, 'h': 1200, 'resize': 'fit'}}}]})
# ('favorited', False)
# ('retweeted', False)
# ('possibly_sensitive', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386357665')
#
# ('created_at', 'Sun Aug 08 01:32:38 +0000 2021')
# ('id', 1424181728155951110)
# ('id_str', '1424181728155951110')
# ('text', 'comecei a pensar aqui e acho que eu deveria deixar alguém incumbido da tarefa de desbloquear meu celular e acessar… https://t.co/yhl7rXenKw')
# ('source', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>')
# ('truncated', True)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 55415386, 'id_str': '55415386', 'name': 'a mina do RH ψ |-/', 'screen_name': 'gabr1nhela', 'location': None, 'url': 'http://instagram.com/_gabsvicente', 'description': 'i wish i was dead sometimes, haha, i’m just kidding 🥴 🧲 || she/her 🏳️\u200d🌈', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 707, 'friends_count': 417, 'listed_count': 10, 'favourites_count': 21582, 'statuses_count': 114224, 'created_at': 'Fri Jul 10 00:35:57 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'ACDED6', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_tile': False, 'profile_link_color': '038543', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'F6F6F6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1417272497519702019/Q7psDwlY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1417272497519702019/Q7psDwlY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/55415386/1609111915', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('extended_tweet', {'full_text': 'comecei a pensar aqui e acho que eu deveria deixar alguém incumbido da tarefa de desbloquear meu celular e acessar minhas redes quando eu morrer', 'display_text_range': [0, 144], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}})
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [{'url': 'https://t.co/yhl7rXenKw', 'expanded_url': 'https://twitter.com/i/web/status/1424181728155951110', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386358666')
#
# ('created_at', 'Sun Aug 08 01:32:39 +0000 2021')
# ('id', 1424181732350251012)
# ('id_str', '1424181732350251012')
# ('text', 'q crush é esse senhor ???????????')
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', False)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 1022522591985258497, 'id_str': '1022522591985258497', 'name': 'quem é ela', 'screen_name': 'm_rcelly9', 'location': None, 'url': None, 'description': 'falo muita merda, desculpa', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 78, 'friends_count': 74, 'listed_count': 0, 'favourites_count': 22498, 'statuses_count': 20943, 'created_at': 'Thu Jul 26 16:42:38 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1422708200894312449/nsRN1OqN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1422708200894312449/nsRN1OqN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1022522591985258497/1596302970', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386359666')
#
# ('created_at', 'Sun Aug 08 01:32:39 +0000 2021')
# ('id', 1424181732320940033)
# ('id_str', '1424181732320940033')
# ('text', 'mo saudades dele 🥺')
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', False)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 1262739356860641280, 'id_str': '1262739356860641280', 'name': 'a sub..stituível 💋🇧🇷', 'screen_name': 'melguinh_', 'location': 'bel air city', 'url': None, 'description': 'filha da lua com gatilhos mentais', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 154, 'friends_count': 310, 'listed_count': 1, 'favourites_count': 9943, 'statuses_count': 8275, 'created_at': 'Tue May 19 13:38:28 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1421474453377142791/4X6RXYh0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1421474453377142791/4X6RXYh0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1262739356860641280/1627740995', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386359659')
#
# ('created_at', 'Sun Aug 08 01:32:39 +0000 2021')
# ('id', 1424181732341866499)
# ('id_str', '1424181732341866499')
# ('text', 'mano era só um namorado, odeio ficar na carência, q ódio')
# ('source', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>')
# ('truncated', False)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 1279969315152953344, 'id_str': '1279969315152953344', 'name': 'stephany', 'screen_name': 'stephanyrent', 'location': 'Recreio, Brasil', 'url': None, 'description': '@flamengo', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 98, 'friends_count': 185, 'listed_count': 0, 'favourites_count': 754, 'statuses_count': 1410, 'created_at': 'Mon Jul 06 02:44:16 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1422414784402710534/nU-yLdtZ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1422414784402710534/nU-yLdtZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1279969315152953344/1627965328', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386359664')
# ('created_at', 'Sun Aug 08 01:32:40 +0000 2021')
# ('id', 1424181736527781895)
# ('id_str', '1424181736527781895')
# ('text', '@juanvaleixo 2 anos de muita leitura🙏')
# ('display_text_range', [13, 37])
# ('source', '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>')
# ('truncated', False)
# ('in_reply_to_status_id', 1424179061920870404)
# ('in_reply_to_status_id_str', '1424179061920870404')
# ('in_reply_to_user_id', 624606970)
# ('in_reply_to_user_id_str', '624606970')
# ('in_reply_to_screen_name', 'juanvaleixo')
# ('user', {'id': 1159601554732867584, 'id_str': '1159601554732867584', 'name': 'Vega', 'screen_name': 'iarainstein', 'location': 'Na bad', 'url': None, 'description': 'time is relative          menos quando é pra derrubar o governo, já passou da hora dessa merda acontecer', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 47, 'friends_count': 145, 'listed_count': 0, 'favourites_count': 7125, 'statuses_count': 2277, 'created_at': 'Thu Aug 08 23:05:29 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1332860071966085121/Uwzobi1q_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1332860071966085121/Uwzobi1q_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1159601554732867584/1605997433', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'juanvaleixo', 'name': 'ruru', 'id': 624606970, 'id_str': '624606970', 'indices': [0, 12]}], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386360662')
#
# ('created_at', 'Sun Aug 08 01:32:40 +0000 2021')
# ('id', 1424181736536219650)
# ('id_str', '1424181736536219650')
# ('text', 'Não concordo  com essa expulsão do Felipe,Deyverson chegou por cima do pé volante, inclusive acho que a falta era do Fortaleza.')
# ('source', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>')
# ('truncated', False)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 1370477785920245760, 'id_str': '1370477785920245760', 'name': 'Felipe Carvalho ( EL Cancelado)🇫🇷🦁', 'screen_name': 'FCarvalho1918', 'location': 'Fortaleza, Brasil', 'url': 'https://www.instagram.com/p/CMYRBygnKdW/?igshid=1j5foom1nf08v', 'description': 'Sócio Torcedor do Fortaleza esporte clube, Administrador/Redator do portal Manchete1918. Sigam o Manchete no Twitter e no Instagram🇫🇷', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 647, 'friends_count': 69, 'listed_count': 2, 'favourites_count': 5015, 'statuses_count': 5735, 'created_at': 'Fri Mar 12 20:52:34 +0000 2021', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1422583032196763648/8gIjJVXX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1422583032196763648/8gIjJVXX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1370477785920245760/1615696016', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386360664')
#
# ('created_at', 'Sun Aug 08 01:32:40 +0000 2021')
# ('id', 1424181736519393280)
# ('id_str', '1424181736519393280')
# ('text', '@cecicsta Vou assistir agora, espero não me decepcionar.')
# ('display_text_range', [10, 56])
# ('source', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>')
# ('truncated', False)
# ('in_reply_to_status_id', 1424171164541329408)
# ('in_reply_to_status_id_str', '1424171164541329408')
# ('in_reply_to_user_id', 67399761)
# ('in_reply_to_user_id_str', '67399761')
# ('in_reply_to_screen_name', 'cecicsta')
# ('user', {'id': 194282415, 'id_str': '194282415', 'name': 'Kleber Carvalho', 'screen_name': 'KleberFisio', 'location': 'Garanhuns', 'url': None, 'description': 'Fisioterapeuta, apaixonado por futebol e pelo Sport Club do Recife.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 82, 'friends_count': 375, 'listed_count': 0, 'favourites_count': 11912, 'statuses_count': 1007, 'created_at': 'Thu Sep 23 20:31:28 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'A60707', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': 'BD0404', 'profile_sidebar_border_color': 'B50606', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '362720', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1323023246015500288/ydstQHD7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1323023246015500288/ydstQHD7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/194282415/1402719754', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'cecicsta', 'name': 'ceci', 'id': 67399761, 'id_str': '67399761', 'indices': [0, 9]}], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386360660')
#
# ('created_at', 'Sun Aug 08 01:32:40 +0000 2021')
# ('id', 1424181736540360704)
# ('id_str', '1424181736540360704')
# ('text', 'RT @vic_catoala: Postando só pra mostrar que cortei o cabelo kkkkk💕 https://t.co/CEMgBEuViJ')
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a
<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', True)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 1255590395779731459, 'id_str': '1255590395779731459', 'name': 'meri', 'screen_name': 'diseasers', 'location': 'ela/dela', 'url': 'https://aquarela.carrd.co/', 'description': '바로 그곳이 mi casa ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏ ͏͏', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 73, 'friends_count': 89, 'listed_count': 4, 'favourites_count': 27237, 'statuses_count': 8439, 'created_at': 'Wed Apr 29 20:11:02 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1423779689009713153/GwTg2vM2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1423779689009713153/GwTg2vM2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1255590395779731459/1623497884', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('quoted_status_id', 1424170223092092929)
# ('quoted_status_id_str', '1424170223092092929')
# ('quoted_status', {'created_at': 'Sun Aug 08 00:46:55 +0000 2021', 'id': 1424170223092092929, 'id_str': '1424170223092092929', 'text': 'tema: pessoas de nome composto e sua superioridade acima de pessoas de nomes simples e como combater esse sentimento', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1361051681065213956, 'id_str': '1361051681065213956', 'name': 'jhu seokjin', 'screen_name': 'chaeraspring', 'location': 'more&more, 𝘁𝘄𝗶𝗰𝗲.♡ ', 'url': 'https://jhucraft.carrd.co/', 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 607, 'friends_count': 894, 'listed_count': 14, 'favourites_count': 25295, 'statuses_count': 28506, 'created_at': 'Sun Feb 14 20:36:31 +0000 2021', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1417665801704849408/A7IhO1uL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1417665801704849408/A7IhO1uL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1361051681065213956/1628218910', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 63, 'reply_count': 15, 'retweet_count': 1, 'favorite_count': 8, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'pt'})
# ('quoted_status_permalink', {'url': 'https://t.co/BPFY1GttGe', 'expanded': 'https://twitter.com/chaeraspring/status/1424170223092092929', 'display': 'twitter.com/chaeraspring/s…'})
# ('is_quote_status', True)
# ('extended_tweet', {'full_text': 'eu tenho é raiva, gosto mais do primeiro mas ele é totalmente imemorável e insignificante aí só chamam pelo segundo 💔💔', 'display_text_range': [0, 118], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}})
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [{'url': 'https://t.co/sjkgBzlgEm', 'expanded_url': 'https://twitter.com/i/web/status/1424181744903806979', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [], 'symbols': []})
# ('favorited', False)
# ('retweeted', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386362659')
#
# ('created_at', 'Sun Aug 08 01:32:42 +0000 2021')
# ('id', 1424181744916471808)
# ('id_str', '1424181744916471808')
# ('text', 'NOSSA GENTE SERIOKKKKKKKK https://t.co/DxX3JCB8Ak')
# ('display_text_range', [0, 25])
# ('source', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>')
# ('truncated', False)
# ('in_reply_to_status_id', None)
# ('in_reply_to_status_id_str', None)
# ('in_reply_to_user_id', None)
# ('in_reply_to_user_id_str', None)
# ('in_reply_to_screen_name', None)
# ('user', {'id': 1420609064359301123, 'id_str': '1420609064359301123', 'name': 'gio', 'screen_name': 'wilmoncakes', 'location': 'feliz natal', 'url': None, 'description': 'mundinho omar e edvin br', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 115, 'friends_count': 127, 'listed_count': 4, 'favourites_count': 322, 'statuses_count': 486, 'created_at': 'Thu Jul 29 04:56:20 +0000 2021', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1422209973023555589/i9BJN2m9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1422209973023555589/i9BJN2m9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1420609064359301123/1627916285', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []})
# ('geo', None)
# ('coordinates', None)
# ('place', None)
# ('contributors', None)
# ('is_quote_status', False)
# ('quote_count', 0)
# ('reply_count', 0)
# ('retweet_count', 0)
# ('favorite_count', 0)
# ('entities', {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': [], 'media': [{'id': 1424181741993054211, 'id_str': '1424181741993054211', 'indices': [26, 49], 'media_url': 'http://pbs.twimg.com/media/E8O1v6sX0AMPi9Y.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E8O1v6sX0AMPi9Y.jpg', 'url': 'https://t.co/DxX3JCB8Ak', 'display_url': 'pic.twitter.com/DxX3JCB8Ak', 'expanded_url': 'https://twitter.com/wilmoncakes/status/1424181744916471808/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 340, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 719, 'h': 360, 'resize': 'fit'}, 'large': {'w': 719, 'h': 360, 'resize': 'fit'}}}]})
# ('extended_entities', {'media': [{'id': 1424181741993054211, 'id_str': '1424181741993054211', 'indices': [26, 49], 'media_url': 'http://pbs.twimg.com/media/E8O1v6sX0AMPi9Y.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E8O1v6sX0AMPi9Y.jpg', 'url': 'https://t.co/DxX3JCB8Ak', 'display_url': 'pic.twitter.com/DxX3JCB8Ak', 'expanded_url': 'https://twitter.com/wilmoncakes/status/1424181744916471808/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 340, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 719, 'h': 360, 'resize': 'fit'}, 'large': {'w': 719, 'h': 360, 'resize': 'fit'}}}]})
# ('favorited', False)
# ('retweeted', False)
# ('possibly_sensitive', False)
# ('filter_level', 'low')
# ('lang', 'pt')
# ('timestamp_ms', '1628386362662')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26487/2723508740.py in <module>
#     106     stream = Stream(auth, listener)
#     107
# --> 108     stream.sample(languages=['pt'])
#     109
#     110     # search twitter for "congress" keyword
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in sample(self, is_async, languages, stall_warnings)
#     447         if stall_warnings:
#     448             self.session.params['stall_warnings'] = 'true'
# --> 449         self._start(is_async)
#     450
#     451     def filter(self, follow=None, track=None, is_async=False, locations=None,
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /usr/lib/python3/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# /usr/lib/python3.8/http/client.py in read(self, amt)
#     453             # Amount is given, implement using readinto
#     454             b = bytearray(amt)
# --> 455             n = self.readinto(b)
#     456             return memoryview(b)[:n].tobytes()
#     457         else:
#
# /usr/lib/python3.8/http/client.py in readinto(self, b)
#     487
#     488         if self.chunked:
# --> 489             return self._readinto_chunked(b)
#     490
#     491         if self.length is not None:
#
# /usr/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     582         try:
#     583             while True:
# --> 584                 chunk_left = self._get_chunk_left()
#     585                 if chunk_left is None:
#     586                     return total_bytes
#
# /usr/lib/python3.8/http/client.py in _get_chunk_left(self)
#     550                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     551             try:
# --> 552                 chunk_left = self._read_next_chunk_size()
#     553             except ValueError:
#     554                 raise IncompleteRead(b'')
#
# /usr/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     510     def _read_next_chunk_size(self):
#     511         # Read the next chunk size from the file
# --> 512         line = self.fp.readline(_MAXLINE + 1)
#     513         if len(line) > _MAXLINE:
#     514             raise LineTooLong("chunk size")
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
