# %%
import json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime as dt 
from elasticsearch import Elasticsearch
import tweepy
from config import *

es = Elasticsearch()


class TweetStreamListener(StreamListener):

    def on_data(self, data):

        # decode json
        dict_data = json.loads(data)
       
    
    
    
        coord = dict_data["coordinates"]
        if coord is not None:
            coord = dict_data["coordinates"]
            lan = dict_data["coordinates"][0]
            lat = dict_data["coordinates"][1]
        else:
            coord = "None"
    
    
        tweet_date = dict_data['created_at']
        username = dict_data['user']['name']
        account_creation_date = dict_data['created_at']
        user_description = dict_data['user']['description']
        user_url = dict_data['user']['url']
        verified_status = dict_data['user']['verified']
        source = dict_data['source'][:]
        friends_count = dict_data['user']['friends_count']
        followers_count = dict_data['user']['followers_count']
        retweeted_count = dict_data['retweet_count']
        favorite_count = dict_data['favorite_count']
        hashtags = dict_data['entities']['hashtags']
        location = dict_data["user"]["location"]
        
        tweet_full_text = dict_data['text']
        
        # preparando os dados para o elasticsearch
        doc = {
            '@timestamp': dt.now(),
            'data_tweet': tweet_date,
            'nome': str(username),
            'perfil_criado': str(account_creation_date),
            'descricao_usuario': str(user_description),
            'url_usuario': str(user_url),
            'user_verificado': bool(verified_status),
            'source': str(source),
            'seguindo': int(friends_count),
            'seguidores': int(followers_count),
            'retweets': int(retweeted_count),
            'likes': int(favorite_count),
            'hashtags': hashtags,
            'location': str(location),
            'tweet_full_text': str(tweet_full_text),
            'word_list': str(tweet_full_text).split(' '),
            "coordinates": coord
        }
        
        
        
        # add text and sentiment info to elasticsearch
        es.index(index="twitter_indexx", body=doc)
#                  
                 
#                  body={dict_data["user"]["screen_name"],
#                           dict_data["timestamp_ms"],
#                           dict_data["created_at"], # unfortunately this gets stored as a string
#                           dict_data["user"]["location"], # user location
#                           dict_data["text"])
        
        for d in doc.items():
            print(d)
            
        print('')              
        return True

    # on failure
    def on_error(self, status):
        print(status)

if __name__ == '__main__':

    # create instance of the tweepy tweet stream listener
    listener = TweetStreamListener()

    # set twitter keys/tokens
    consumer_key="lOjJGrF8QybsC1eBNEqYCgKjW"
    consumer_secret="W0uvZLOwZANbUZwbpHHfrmCTv4nJ6G0CjBgoGNs8QwAbyKaABt"
    access_token="1396467357724315650-N12JYtGuTFnBqc3zJ2Jkn2mDYh1J3s"
    access_token_secret="94VIdoc9Vp9EyuIDUUQSbMlrANuRYjf2DbNWKOBf6Bjen"
    
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    # create instance of the tweepy stream
    stream = Stream(auth, listener)
    
    stream.sample(languages=['pt'])

    # search twitter for "congress" keyword
    stream.filter(track=["messi", "psg", "barcelona"])
# Out:
# /usr/local/lib/python3.8/dist-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.14/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 50, 986775))
# ('data_tweet', 'Sun Aug 08 23:51:44 +0000 2021')
# ('nome', 'Joelson Rodrigues')
# ('perfil_criado', 'Sun Aug 08 23:51:44 +0000 2021')
# ('descricao_usuario', '🇧🇷')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 146)
# ('seguidores', 29)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'São Paulo, Brasil')
# ('tweet_full_text', '@lacerdaa_Leo @josecarlosdutr6 @OrleansTiago @BolsonaroSP Não adianta discutir mano , gado é gado não quer saber da realidade ..')
# ('word_list', ['@lacerdaa_Leo', '@josecarlosdutr6', '@OrleansTiago', '@BolsonaroSP', 'Não', 'adianta', 'discutir', 'mano', ',', 'gado', 'é', 'gado', 'não', 'quer', 'saber', 'da', 'realidade', '..'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 51, 24359))
# ('data_tweet', 'Sun Aug 08 23:51:44 +0000 2021')
# ('nome', 'Paola Bracho')
# ('perfil_criado', 'Sun Aug 08 23:51:44 +0000 2021')
# ('descricao_usuario', 'I wanna move out of the black into the blue\n\n𝑇ℎ𝑎𝑛𝑘 𝑦𝑜𝑢, 𝐾𝑖𝑚 𝐽𝑜𝑛𝑔ℎ𝑦𝑢𝑛 \n\nꜱʜɪɴᴇᴇ ᴡᴏʀʟᴅ (140607, 150425, 210404)')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 304)
# ('seguidores', 244)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', "Jessica's Golden Sky")
# ('tweet_full_text', 'Pois eu to preferindo mil vezes seguir os poucos influencers BR e atletas gringos que sigo porque a maioria das pes… https://t.co/7pm4PRlrDg')
# ('word_list', ['Pois', 'eu', 'to', 'preferindo', 'mil', 'vezes', 'seguir', 'os', 'poucos', 'influencers', 'BR', 'e', 'atletas', 'gringos', 'que', 'sigo', 'porque', 'a', 'maioria', 'das', 'pes…', 'https://t.co/7pm4PRlrDg'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 51, 273000))
# ('data_tweet', 'Sun Aug 08 23:51:45 +0000 2021')
# ('nome', 'Lyla Brito⁷ ∞')
# ('perfil_criado', 'Sun Aug 08 23:51:45 +0000 2021')
# ('descricao_usuario', 'Agradecer é a arte de atrair coisas boas  🌟 | Farmacêutica, Vestibulanda, Tiktoker e Only ARMY  | borahae bangtan @bts_twt 💜')
# ('url_usuario', 'http://Instagram.com/ly_brito')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 579)
# ('seguidores', 265)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [{'text': 'BTS', 'indices': [39, 43]}, {'text': 'Butter', 'indices': [47, 54]}, {'text': 'ARMY', 'indices': [57, 62]}, {'text': 'KCAMexico', 'indices': [77, 87]}])
# ('location', 'Brasil ')
# ('tweet_full_text', 'RT @BTSProjectBR: RT= VOTO\n\nEu voto em #BTS\xa0\xa0, #Butter e #ARMY (@BTS_twt) no #KCAMexico 2021')
# ('word_list', ['RT', '@BTSProjectBR:', 'RT=', 'VOTO\n\nEu', 'voto', 'em', '#BTS\xa0\xa0,', '#Butter', 'e', '#ARMY', '(@BTS_twt)', 'no', '#KCAMexico', '2021'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 51, 281051))
# ('data_tweet', 'Sun Aug 08 23:51:45 +0000 2021')
# ('nome', 'マテウス (INFJ-T)')
# ('perfil_criado', 'Sun Aug 08 23:51:45 +0000 2021')
# ('descricao_usuario', 'Always under construction 2️⃣8️⃣ / ✝️ / ⚖️📚 / ♐️ / ✈️🌎 / 🌈 / 🧙🦅💙 / 🐷⚽️💚 / 💉')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 741)
# ('seguidores', 115)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [{'text': 'AppleMusic', 'indices': [24, 35]}])
# ('location', 'São José do Rio Preto')
# ('tweet_full_text', 'Voltei a ser putinha do #AppleMusic socorro @AppleMusic')
# ('word_list', ['Voltei', 'a', 'ser', 'putinha', 'do', '#AppleMusic', 'socorro', '@AppleMusic'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 52, 415812))
# ('data_tweet', 'Sun Aug 08 23:51:46 +0000 2021')
# ('nome', 'Diego eL Payaso')
# ('perfil_criado', 'Sun Aug 08 23:51:46 +0000 2021')
# ('descricao_usuario', 'Antes de casar lembre-se, OPC tá on!')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 448)
# ('seguidores', 111)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @LedioLegal: @LegalLedio Não, mas o rebaixado já pintou.\n\nLegal')
# ('word_list', ['RT', '@LedioLegal:', '@LegalLedio', 'Não,', 'mas', 'o', 'rebaixado', 'já', 'pintou.\n\nLegal'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 52, 430346))
# ('data_tweet', 'Sun Aug 08 23:51:46 +0000 2021')
# ('nome', 'manu')
# ('perfil_criado', 'Sun Aug 08 23:51:46 +0000 2021')
# ('descricao_usuario', 'eu meus gatinhos i meu jimin💭')
# ('url_usuario', 'https://jminlovie.carrd.co/')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 333)
# ('seguidores', 458)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'nyny')
# ('tweet_full_text', 'minha header🙁💗')
# ('word_list', ['minha', 'header🙁💗'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 52, 439329))
# ('data_tweet', 'Sun Aug 08 23:51:46 +0000 2021')
# ('nome', 'anna')
# ('perfil_criado', 'Sun Aug 08 23:51:46 +0000 2021')
# ('descricao_usuario', 'minimalista nos sentimentos.')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2355)
# ('seguidores', 699)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'pet sementary')
# ('tweet_full_text', 'RT @legadaodamassa: BICHO O DARLAN ALÉM DE SER RECEBIDO COM UM MURAL LINDÃO FEITO PELA FILHA, RECEBEU UMA CESTA DE PÃES DOS VIZINHO E POSTO…')
# ('word_list', ['RT', '@legadaodamassa:', 'BICHO', 'O', 'DARLAN', 'ALÉM', 'DE', 'SER', 'RECEBIDO', 'COM', 'UM', 'MURAL', 'LINDÃO', 'FEITO', 'PELA', 'FILHA,', 'RECEBEU', 'UMA', 'CESTA', 'DE', 'PÃES', 'DOS', 'VIZINHO', 'E', 'POSTO…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 52, 643830))
# ('data_tweet', 'Sun Aug 08 23:51:46 +0000 2021')
# ('nome', 'lau')
# ('perfil_criado', 'Sun Aug 08 23:51:46 +0000 2021')
# ('descricao_usuario', '@flamengo')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 489)
# ('seguidores', 625)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Rio de Janeiro, Brasil')
# ('tweet_full_text', '@AliceBravim eu também sou assim KKKKKK')
# ('word_list', ['@AliceBravim', 'eu', 'também', 'sou', 'assim', 'KKKKKK'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 52, 653047))
# ('data_tweet', 'Sun Aug 08 23:51:46 +0000 2021')
# ('nome', 'Rebequinha ᶜʳᶠ')
# ('perfil_criado', 'Sun Aug 08 23:51:46 +0000 2021')
# ('descricao_usuario', '✨ @flamengo ♥️🖤')
# ('url_usuario', 'https://www.instagram.com/_beecamelo/?hl=pt-br')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 127)
# ('seguidores', 97)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Rio de Janeiro, Brasil')
# ('tweet_full_text', 'RT @laucorreeaa: eu nunca entendi duas pessoas que se amam não ficarem juntas, até vivenciar.')
# ('word_list', ['RT', '@laucorreeaa:', 'eu', 'nunca', 'entendi', 'duas', 'pessoas', 'que', 'se', 'amam', 'não', 'ficarem', 'juntas,', 'até', 'vivenciar.'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 52, 872055))
# ('data_tweet', 'Sun Aug 08 23:51:46 +0000 2021')
# ('nome', 'KL')
# ('perfil_criado', 'Sun Aug 08 23:51:46 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2476)
# ('seguidores', 5102)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Complexo do Alemão')
# ('tweet_full_text', 'Alguém me explica?')
# ('word_list', ['Alguém', 'me', 'explica?'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 53, 94009))
# ('data_tweet', 'Sun Aug 08 23:51:47 +0000 2021')
# ('nome', 'Thii')
# ('perfil_criado', 'Sun Aug 08 23:51:47 +0000 2021')
# ('descricao_usuario', 'O Estado não é o seu pai..Então vá trabalhar 💪')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 123)
# ('seguidores', 310)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@IsentaoCast Já pensava desde 2018 q Ciro seria a via Sensata..mtos votaram nele contra PT e Bonoro..Qdo ele é Lula até na alma podre.')
# ('word_list', ['@IsentaoCast', 'Já', 'pensava', 'desde', '2018', 'q', 'Ciro', 'seria', 'a', 'via', 'Sensata..mtos', 'votaram', 'nele', 'contra', 'PT', 'e', 'Bonoro..Qdo', 'ele', 'é', 'Lula', 'até', 'na', 'alma', 'podre.'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 53, 107826))
# ('data_tweet', 'Sun Aug 08 23:51:47 +0000 2021')
# ('nome', 'house of Ross vacinadoh 🐊')
# ('perfil_criado', 'Sun Aug 08 23:51:47 +0000 2021')
# ('descricao_usuario', 'arquiteto, geminiano y vila buarqueer')
# ('url_usuario', 'http://instagram.com/hugorossini/')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 712)
# ('seguidores', 319)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'São Paulo, Brasil')
# ('tweet_full_text', '@jaoadymello A dona Zilda é um ícone 😍')
# ('word_list', ['@jaoadymello', 'A', 'dona', 'Zilda', 'é', 'um', 'ícone', '😍'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 54, 16959))
# ('data_tweet', 'Sun Aug 08 23:51:48 +0000 2021')
# ('nome', '𝑪𝒊𝒏𝒅𝒆𝒓𝒆𝒍𝒂')
# ('perfil_criado', 'Sun Aug 08 23:51:48 +0000 2021')
# ('descricao_usuario', 'tudo posso naquele que me fortalecer!/16years🤍🕊')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 130)
# ('seguidores', 195)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Guarujá, Brasil')
# ('tweet_full_text', 'Meudeus que vontade de chorar ate deus sair do céu e falar “vamos filha chegou sua hra”')
# ('word_list', ['Meudeus', 'que', 'vontade', 'de', 'chorar', 'ate', 'deus', 'sair', 'do', 'céu', 'e', 'falar', '“vamos', 'filha', 'chegou', 'sua', 'hra”'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 54, 30986))
# ('data_tweet', 'Sun Aug 08 23:51:48 +0000 2021')
# ('nome', 'ؘ')
# ('perfil_criado', 'Sun Aug 08 23:51:48 +0000 2021')
# ('descricao_usuario', 'she/her')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 1335)
# ('seguidores', 5057)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'misha deserves the world')
# ('tweet_full_text', '@SeriesBrasil o maior de todos')
# ('word_list', ['@SeriesBrasil', 'o', 'maior', 'de', 'todos'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 54, 983123))
# ('data_tweet', 'Sun Aug 08 23:51:49 +0000 2021')
# ('nome', 'colégio miles * vagas abertas')
# ('perfil_criado', 'Sun Aug 08 23:51:49 +0000 2021')
# ('descricao_usuario', 'vem aí')
# ('url_usuario', 'https://colegiomiles.carrd.co/')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 248)
# ('seguidores', 377)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@gatinhesufst lembrei da nossa professora de portugues')
# ('word_list', ['@gatinhesufst', 'lembrei', 'da', 'nossa', 'professora', 'de', 'portugues'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 54, 997112))
# ('data_tweet', 'Sun Aug 08 23:51:49 +0000 2021')
# ('nome', 'dmc')
# ('perfil_criado', 'Sun Aug 08 23:51:49 +0000 2021')
# ('descricao_usuario', 'À minha mesa sentam os excluídos. Vou ver se eles te arrumam um espaço..')
# ('url_usuario', 'http://instagram.com/dmc.docx')
# ('user_verificado', False)
# ('source', '9789998?mt=12" rel="nofollow">Twitter for Mac</a>')
# ('seguindo', 214)
# ('seguidores', 88)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@FoxSportsBrasil Não fez nem sentido essa declaração.')
# ('word_list', ['@FoxSportsBrasil', 'Não', 'fez', 'nem', 'sentido', 'essa', 'declaração.'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 55, 212168))
# ('data_tweet', 'Sun Aug 08 23:51:49 +0000 2021')
# ('nome', 'tadeuzao1960')
# ('perfil_criado', 'Sun Aug 08 23:51:49 +0000 2021')
# ('descricao_usuario', 'Um Brasil 🇧🇷 mais justo e solidário em 2022!!!!!! Lula e Haddad!!!🇧🇷⭐️')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 517)
# ('seguidores', 516)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @alexmcoe1: @ManuelaDavila 2024 é o Brasil em Paris.\n \nO Ciro vai antes.\nUh lá lá! 😁🇨🇵 https://t.co/EWQEdMHDRx')
# ('word_list', ['RT', '@alexmcoe1:', '@ManuelaDavila', '2024', 'é', 'o', 'Brasil', 'em', 'Paris.\n', '\nO', 'Ciro', 'vai', 'antes.\nUh', 'lá', 'lá!', '😁🇨🇵', 'https://t.co/EWQEdMHDRx'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 55, 935224))
# ('data_tweet', 'Sun Aug 08 23:51:50 +0000 2021')
# ('nome', 'pedro')
# ('perfil_criado', 'Sun Aug 08 23:51:50 +0000 2021')
# ('descricao_usuario', 'a little sympathy i hope you can show me')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 404)
# ('seguidores', 180)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'fan acc. @sooyaasluv')
# ('tweet_full_text', 'bixin a netflix só pode tá de palhaçada com esse final de move to heaven né?? vai ser igual vagabond essa porra, certeza!')
# ('word_list', ['bixin', 'a', 'netflix', 'só', 'pode', 'tá', 'de', 'palhaçada', 'com', 'esse', 'final', 'de', 'move', 'to', 'heaven', 'né??', 'vai', 'ser', 'igual', 'vagabond', 'essa', 'porra,', 'certeza!'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 55, 945693))
# ('data_tweet', 'Sun Aug 08 23:51:50 +0000 2021')
# ('nome', '۫isa!¡')
# ('perfil_criado', 'Sun Aug 08 23:51:50 +0000 2021')
# ('descricao_usuario', 'shoto é verdade que você ama o @ennataki?')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 791)
# ('seguidores', 742)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'não siga se for anti-pan! ')
# ('tweet_full_text', 'RT @manu2sexo: te defendi p todo mundo p no final vc ser tudo oq falavam')
# ('word_list', ['RT', '@manu2sexo:', 'te', 'defendi', 'p', 'todo', 'mundo', 'p', 'no', 'final', 'vc', 'ser', 'tudo', 'oq', 'falavam'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 56, 168035))
# ('data_tweet', 'Sun Aug 08 23:51:50 +0000 2021')
# ('nome', 'Cintia Beraldo')
# ('perfil_criado', 'Sun Aug 08 23:51:50 +0000 2021')
# ('descricao_usuario', '”De tanto ver agigantarem-se os poderes nas mãos dos maus, o homem chega a desanimar-se da virtude, a rir-se da honra e ter vergonha de ser honesto” Rui Barbosa')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 530)
# ('seguidores', 579)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @alesilva_38: Amanhã estarei indo para Brasília e devo passar a semana inteira por lá. Apesar de ser apenas suplente junto a CCJC, conte…')
# ('word_list', ['RT', '@alesilva_38:', 'Amanhã', 'estarei', 'indo', 'para', 'Brasília', 'e', 'devo', 'passar', 'a', 'semana', 'inteira', 'por', 'lá.', 'Apesar', 'de', 'ser', 'apenas', 'suplente', 'junto', 'a', 'CCJC,', 'conte…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 56, 176703))
# ('data_tweet', 'Sun Aug 08 23:51:50 +0000 2021')
# ('nome', 'kitty.')
# ('perfil_criado', 'Sun Aug 08 23:51:50 +0000 2021')
# ('descricao_usuario', 'oi\nela/dela')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 32)
# ('seguidores', 6)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@dyeackerman KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK A GATA ME BLOQUEO NAO AGUENTO')
# ('word_list', ['@dyeackerman', 'KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK', 'A', 'GATA', 'ME', 'BLOQUEO', 'NAO', 'AGUENTO'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 56, 369939))
# ('data_tweet', 'Sun Aug 08 23:51:50 +0000 2021')
# ('nome', 'Ghezz 🗡| 📖: Tog⁷')
# ('perfil_criado', 'Sun Aug 08 23:51:50 +0000 2021')
# ('descricao_usuario', '➝ ʙᴏᴏᴋsᴛᴀɴ, ᴅᴏʀᴀᴍᴇɪʀᴀ, ᴄᴀᴅᴇʟɪɴʜᴀ ᴅᴏ ᴀʙᴇʟ ᴇ ᴅᴇ ᴜɴs ᴋʀᴀᴘᴘᴇʀs ᴀɪ   ⌈a/ela/-a⌋')
# ('url_usuario', 'https://www.amazon.com.br/hz/wishlist/ls/1R9MZL6B5V9GE?ref_=wl_share')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2985)
# ('seguidores', 5391)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'R&B/KR&B/KHH')
# ('tweet_full_text', 'RT @Itsletriste: estadunidenses vão fazer o que com a medalha? fritar?')
# ('word_list', ['RT', '@Itsletriste:', 'estadunidenses', 'vão', 'fazer', 'o', 'que', 'com', 'a', 'medalha?', 'fritar?'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 56, 379115))
# ('data_tweet', 'Sun Aug 08 23:51:50 +0000 2021')
# ('nome', 'vitória')
# ('perfil_criado', 'Sun Aug 08 23:51:50 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 515)
# ('seguidores', 332)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Ceará, Brasil')
# ('tweet_full_text', '@chicobarney Posta o vídeo')
# ('word_list', ['@chicobarney', 'Posta', 'o', 'vídeo'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 56, 894417))
# ('data_tweet', 'Sun Aug 08 23:51:51 +0000 2021')
# ('nome', 'Eduardo Sanches')
# ('perfil_criado', 'Sun Aug 08 23:51:51 +0000 2021')
# ('descricao_usuario', 'Minha beleza é tão interior, que daqui a pouco ela se muda para um sítio')
# ('url_usuario', 'https://linktr.ee/OsDoisLadosDaMoeda')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 50)
# ('seguidores', 53)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'Eu falando Usso e vcs nem me falaram nada….vacilo….kkkk')
# ('word_list', ['Eu', 'falando', 'Usso', 'e', 'vcs', 'nem', 'me', 'falaram', 'nada….vacilo….kkkk'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 56, 902711))
# ('data_tweet', 'Sun Aug 08 23:51:51 +0000 2021')
# ('nome', 'YasminNTC')
# ('perfil_criado', 'Sun Aug 08 23:51:51 +0000 2021')
# ('descricao_usuario', 'Não preciso de mais nada, minha vida já está completa.\n||@mirairama @linnamour||')
# ('url_usuario', 'https://youtu.be/8qQGTAwLhbY')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 39)
# ('seguidores', 38)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@Madotsukik_ @marcusoloski seu cu')
# ('word_list', ['@Madotsukik_', '@marcusoloski', 'seu', 'cu'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 57, 215028))
# ('data_tweet', 'Sun Aug 08 23:51:51 +0000 2021')
# ('nome', 'Humberto Blas')
# ('perfil_criado', 'Sun Aug 08 23:51:51 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 157)
# ('seguidores', 14)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Cuba')
# ('tweet_full_text', 'RT @anabmoser: Gente, entrei no site oficial da Olimpíada pra pegar a estatística da final do vôlei e me deparei com este documentário do t…')
# ('word_list', ['RT', '@anabmoser:', 'Gente,', 'entrei', 'no', 'site', 'oficial', 'da', 'Olimpíada', 'pra', 'pegar', 'a', 'estatística', 'da', 'final', 'do', 'vôlei', 'e', 'me', 'deparei', 'com', 'este', 'documentário', 'do', 't…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 57, 435814))
# ('data_tweet', 'Sun Aug 08 23:51:51 +0000 2021')
# ('nome', 'Ady@SG')
# ('perfil_criado', 'Sun Aug 08 23:51:51 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 1892)
# ('seguidores', 7539)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'East Singapore')
# ('tweet_full_text', 'RT @fatihmassage_: AVAILABLE 082217578404 VCS PROMO BESAR 💦✈️\n@Armanpjtjakpus @ma55agekaroshi @TopMssgBdg1 @realpij4t @pijatbogorbot @Agema…')
# ('word_list', ['RT', '@fatihmassage_:', 'AVAILABLE', '082217578404', 'VCS', 'PROMO', 'BESAR', '💦✈️\n@Armanpjtjakpus', '@ma55agekaroshi', '@TopMssgBdg1', '@realpij4t', '@pijatbogorbot', '@Agema…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 57, 445428))
# ('data_tweet', 'Sun Aug 08 23:51:51 +0000 2021')
# ('nome', 'Waldir Patriota🇧🇷🇧🇷Bonoro🇺🇦🇺🇦')
# ('perfil_criado', 'Sun Aug 08 23:51:51 +0000 2021')
# ('descricao_usuario', 'Anti Comunistas/ terceira conta/sdv\n🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇺🇦')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 1474)
# ('seguidores', 991)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @NellyYumi: Manifestação à noite em Brasília? 🤔🤔🤔 https://t.co/xDQDrLld0Z')
# ('word_list', ['RT', '@NellyYumi:', 'Manifestação', 'à', 'noite', 'em', 'Brasília?', '🤔🤔🤔', 'https://t.co/xDQDrLld0Z'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 58, 403082))
# ('data_tweet', 'Sun Aug 08 23:51:52 +0000 2021')
# ('nome', 'kari ☽︎☾')
# ('perfil_criado', 'Sun Aug 08 23:51:52 +0000 2021')
# ('descricao_usuario', "#mako: i've got your back and i always will.  • check carrd before following!! • pt/br | eng")
# ('url_usuario', 'http://goldenzutara.carrd.co/')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 308)
# ('seguidores', 339)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'she/they • afro latina •')
# ('tweet_full_text', '@asleeplynch vazou a yue stan, amei')
# ('word_list', ['@asleeplynch', 'vazou', 'a', 'yue', 'stan,', 'amei'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 58, 415978))
# ('data_tweet', 'Sun Aug 08 23:51:52 +0000 2021')
# ('nome', 'eloá (garay supremacy) 🇧🇷')
# ('perfil_criado', 'Sun Aug 08 23:51:52 +0000 2021')
# ('descricao_usuario', '𝗯𝗲𝘆𝗼𝗻𝗰𝗲 • 𝗿𝗶𝗵𝗮𝗻𝗻𝗮 • 𝗹𝘂𝗱𝗺𝗶𝗹𝗹𝗮 • 𝗻𝗶𝗰𝗸𝗶')
# ('url_usuario', 'https://instagram.com/stayludmilla?utm_medium=copy_link')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 3689)
# ('seguidores', 2109)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Ceará, Brasil')
# ('tweet_full_text', 'RT @poolsdrunk: o aleatório saindo de rocket pra heaven\n\nhttps://t.co/syINA0FRLL')
# ('word_list', ['RT', '@poolsdrunk:', 'o', 'aleatório', 'saindo', 'de', 'rocket', 'pra', 'heaven\n\nhttps://t.co/syINA0FRLL'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 59, 460059))
# ('data_tweet', 'Sun Aug 08 23:51:53 +0000 2021')
# ('nome', 'thai.')
# ('perfil_criado', 'Sun Aug 08 23:51:53 +0000 2021')
# ('descricao_usuario', '@Flamengo')
# ('url_usuario', 'https://www.instagram.com/thainaxmedeiros/')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 3977)
# ('seguidores', 4292)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@elianacust q ódio vei')
# ('word_list', ['@elianacust', 'q', 'ódio', 'vei'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 59, 471950))
# ('data_tweet', 'Sun Aug 08 23:51:53 +0000 2021')
# ('nome', 'ؘ 🦉')
# ('perfil_criado', 'Sun Aug 08 23:51:53 +0000 2021')
# ('descricao_usuario', 'lisa quem sou eu sem vc')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 10047)
# ('seguidores', 13224)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'rosieposie')
# ('tweet_full_text', 'RT @idolshelpffxofi: FOLLOW TRICK! 🦉\n\n• RT/FAV esse tweet para ganhar seguidores!\n• Siga todos que RT e FAV!\n• Siga de volta todos que te s…')
# ('word_list', ['RT', '@idolshelpffxofi:', 'FOLLOW', 'TRICK!', '🦉\n\n•', 'RT/FAV', 'esse', 'tweet', 'para', 'ganhar', 'seguidores!\n•', 'Siga', 'todos', 'que', 'RT', 'e', 'FAV!\n•', 'Siga', 'de', 'volta', 'todos', 'que', 'te', 's…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 51, 59, 477633))
# ('data_tweet', 'Sun Aug 08 23:51:53 +0000 2021')
# ('nome', 'madu cat♊')
# ('perfil_criado', 'Sun Aug 08 23:51:53 +0000 2021')
# ('descricao_usuario', 'seja luz✨\ninsta:@maducastroo_')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 53)
# ('seguidores', 80)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Juiz de Fora, Brasil')
# ('tweet_full_text', 'RT @Victori73105928: Eu fico olhando minhas fotos antigas e fico me perguntando aonde que eu deixei essa blusa? E esse short? Kkkkkkkkkkkkk…')
# ('word_list', ['RT', '@Victori73105928:', 'Eu', 'fico', 'olhando', 'minhas', 'fotos', 'antigas', 'e', 'fico', 'me', 'perguntando', 'aonde', 'que', 'eu', 'deixei', 'essa', 'blusa?', 'E', 'esse', 'short?', 'Kkkkkkkkkkkkk…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 0, 435418))
# ('data_tweet', 'Sun Aug 08 23:51:54 +0000 2021')
# ('nome', '뷔itoria')
# ('perfil_criado', 'Sun Aug 08 23:51:54 +0000 2021')
# ('descricao_usuario', 'love bot do taehyung imitando o pingu')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 160)
# ('seguidores', 107)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'vhope appreciation acc')
# ('tweet_full_text', '@s2kimseokjin eu fico com dó :(((( mas vou dropar essa aqui pq tá foda')
# ('word_list', ['@s2kimseokjin', 'eu', 'fico', 'com', 'dó', ':((((', 'mas', 'vou', 'dropar', 'essa', 'aqui', 'pq', 'tá', 'foda'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 0, 446729))
# ('data_tweet', 'Sun Aug 08 23:51:54 +0000 2021')
# ('nome', '𝐌𝐚𝐫𝐭𝐢𝐧 || TOKETEO 🏀')
# ('perfil_criado', 'Sun Aug 08 23:51:54 +0000 2021')
# ('descricao_usuario', '✨Atdmv✨   🌈 ⃤')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2255)
# ('seguidores', 2731)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'kenia Os')
# ('tweet_full_text', 'RT @keniaos: Estou com saudade de vocês! \n\nHahahaha')
# ('word_list', ['RT', '@keniaos:', 'Estou', 'com', 'saudade', 'de', 'vocês!', '\n\nHahahaha'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 0, 456031))
# ('data_tweet', 'Sun Aug 08 23:51:54 +0000 2021')
# ('nome', 'júlia 🐌 || FIC 📌')
# ('perfil_criado', 'Sun Aug 08 23:51:54 +0000 2021')
# ('descricao_usuario', 'eu e khai abraçadinhas na barriga da gigi  — a/ela/dela')
# ('url_usuario', 'https://h0uismalik.carrd.co/')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 371)
# ('seguidores', 348)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'jade thirwall ¡!')
# ('tweet_full_text', '@annsconda tá fazendo oq d bom amg?')
# ('word_list', ['@annsconda', 'tá', 'fazendo', 'oq', 'd', 'bom', 'amg?'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 0, 461356))
# ('data_tweet', 'Sun Aug 08 23:51:54 +0000 2021')
# ('nome', 'FelipiN333🅱️')
# ('perfil_criado', 'Sun Aug 08 23:51:54 +0000 2021')
# ('descricao_usuario', '333')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 91)
# ('seguidores', 47)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@neyzxte Você está rindo do meu flamengo 😭😭😭')
# ('word_list', ['@neyzxte', 'Você', 'está', 'rindo', 'do', 'meu', 'flamengo', '😭😭😭'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 1, 56323))
# ('data_tweet', 'Sun Aug 08 23:51:55 +0000 2021')
# ('nome', '\U0001fa9e')
# ('perfil_criado', 'Sun Aug 08 23:51:55 +0000 2021')
# ('descricao_usuario', '• 𝐌𝐢𝐠𝐮𝐞𝐥🤱🏻 • 𝐇𝐞𝐢𝐭𝐨𝐫 •𝐀𝐧𝐭𝐡𝐨𝐧𝐲 👩\u200d👦\u200d👦')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 1245)
# ('seguidores', 1329)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'Amassei a pizza na força do ódio')
# ('word_list', ['Amassei', 'a', 'pizza', 'na', 'força', 'do', 'ódio'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 1, 376067))
# ('data_tweet', 'Sun Aug 08 23:51:55 +0000 2021')
# ('nome', '.•.• naju · 제니')
# ('perfil_criado', 'Sun Aug 08 23:51:55 +0000 2021')
# ('descricao_usuario', 'eu e a lisa irritando td mundo | ᴏɴʟʏʙʟɪɴᴋ')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 1292)
# ('seguidores', 1311)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Se for army não segue')
# ('tweet_full_text', 'RT @enfpque: enfp’s que ela é tao🥰🥰🥰🥰🥰🥰🥰🥰🥰')
# ('word_list', ['RT', '@enfpque:', 'enfp’s', 'que', 'ela', 'é', 'tao🥰🥰🥰🥰🥰🥰🥰🥰🥰'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 1, 596403))
# ('data_tweet', 'Sun Aug 08 23:51:55 +0000 2021')
# ('nome', 'milena')
# ('perfil_criado', 'Sun Aug 08 23:51:55 +0000 2021')
# ('descricao_usuario', "yeah we some bitches you can't manage")
# ('url_usuario', 'https://rosiesgrf.carrd.co')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 540)
# ('seguidores', 856)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', '  사랑┆𝐁𝐀𝐍𝐆𝐏𝐈𝐍𝐊 ⚠︎')
# ('tweet_full_text', 'true beauty pois sou uma molenga q chora junto com quem sofre')
# ('word_list', ['true', 'beauty', 'pois', 'sou', 'uma', 'molenga', 'q', 'chora', 'junto', 'com', 'quem', 'sofre'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 2, 17456))
# ('data_tweet', 'Sun Aug 08 23:51:56 +0000 2021')
# ('nome', 'tully hart •')
# ('perfil_criado', 'Sun Aug 08 23:51:56 +0000 2021')
# ('descricao_usuario', 'talvez tu entenda (ou não). eu/dela ➢ @Iesbiandades')
# ('url_usuario', 'https://surreallabel.tumblr.com/')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2830)
# ('seguidores', 4472)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'riella 𐋀 ʬ⁸⁴ cloneclub')
# ('tweet_full_text', '@Iesbiandades 10 min só ?????? vou grudar o tempo inteiro fodase')
# ('word_list', ['@Iesbiandades', '10', 'min', 'só', '??????', 'vou', 'grudar', 'o', 'tempo', 'inteiro', 'fodase'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 2, 659233))
# ('data_tweet', 'Sun Aug 08 23:51:56 +0000 2021')
# ('nome', 'Zade')
# ('perfil_criado', 'Sun Aug 08 23:51:56 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'https://instagram.com/sheriff_walker_?igshid=1jkjzv5h0zk15')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 60)
# ('seguidores', 139)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'New York, NY')
# ('tweet_full_text', 'RT @acklesrare: feliz dia dos pais pros maiores pais de supernatural https://t.co/f77AP8JPVn')
# ('word_list', ['RT', '@acklesrare:', 'feliz', 'dia', 'dos', 'pais', 'pros', 'maiores', 'pais', 'de', 'supernatural', 'https://t.co/f77AP8JPVn'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 2, 669652))
# ('data_tweet', 'Sun Aug 08 23:51:56 +0000 2021')
# ('nome', 'Alice')
# ('perfil_criado', 'Sun Aug 08 23:51:56 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 884)
# ('seguidores', 698)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @VlogdoLisboa: PRECISO DESENHAR ✍️? https://t.co/8GuzEQXHyc')
# ('word_list', ['RT', '@VlogdoLisboa:', 'PRECISO', 'DESENHAR', '✍️?', 'https://t.co/8GuzEQXHyc'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 2, 869467))
# ('data_tweet', 'Sun Aug 08 23:51:56 +0000 2021')
# ('nome', 'Piffio - Coach de Presidente/Crítico Jornalístico')
# ('perfil_criado', 'Sun Aug 08 23:51:56 +0000 2021')
# ('descricao_usuario', 'Fake do Maior Presidente criador da Swat Colorada, Baldaice, FricassErnst, frases “Time Grande Não Cai” e “Eu Acredito”.\n\n Só + 1 gremista zoando os colorados.')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 2085)
# ('seguidores', 2391)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Bêra-River')
# ('tweet_full_text', '@Daniloqs @ReidoSul1 Qq o Renato tem a ver com o Inter?')
# ('word_list', ['@Daniloqs', '@ReidoSul1', 'Qq', 'o', 'Renato', 'tem', 'a', 'ver', 'com', 'o', 'Inter?'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 2, 880937))
# ('data_tweet', 'Sun Aug 08 23:51:56 +0000 2021')
# ('nome', 'Laylay👑🌺')
# ('perfil_criado', 'Sun Aug 08 23:51:56 +0000 2021')
# ('descricao_usuario', 'YOONSEOKMIN UTTED🐱☀️🐣🌌\nOnly Army💜\nEla/dela')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 224)
# ('seguidores', 468)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@unhol_ @kenmalovs Ata que susto que em mata do coração??? Poxa mas eu lá tenho culpa 🤧 meu coração tem um fraco po… https://t.co/jqJ7FOOb6I')
# ('word_list', ['@unhol_', '@kenmalovs', 'Ata', 'que', 'susto', 'que', 'em', 'mata', 'do', 'coração???', 'Poxa', 'mas', 'eu', 'lá', 'tenho', 'culpa', '🤧', 'meu', 'coração', 'tem', 'um', 'fraco', 'po…', 'https://t.co/jqJ7FOOb6I'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 2, 898752))
# ('data_tweet', 'Sun Aug 08 23:51:57 +0000 2021')
# ('nome', 'Mundinho Lisa maybe or maybe not br')
# ('perfil_criado', 'Sun Aug 08 23:51:57 +0000 2021')
# ('descricao_usuario', '☆*･*☆ Boiola fanfiqueira, surto por desenho gay, anime, lol, blackpink ☆*･*☆ Ela/Dela @avarosaZahard 🌹🐿/Trisal:@bea_von_daemon❤️\u200d🔥@jojindjarin🐰/@bexbaldur🗡')
# ('url_usuario', 'https://www.spiritfanfiction.com/historia/meu-sonho-esta-no-palco-league-of-legends-kda-18133707')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 890)
# ('seguidores', 938)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Etheria  ')
# ('tweet_full_text', '@Jojindjarin Choramos de tanto amor 😭😭😭')
# ('word_list', ['@Jojindjarin', 'Choramos', 'de', 'tanto', 'amor', '😭😭😭'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 3, 298093))
# ('data_tweet', 'Sun Aug 08 23:51:57 +0000 2021')
# ('nome', 'Σιλας')
# ('perfil_criado', 'Sun Aug 08 23:51:57 +0000 2021')
# ('descricao_usuario', '🏳️\u200d🌈  (he/him/ele/dele)')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 507)
# ('seguidores', 197)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'São Paulo, Brasil')
# ('tweet_full_text', 'RT @jgabrieldiass: eu nunca tive uma relação muito saudável com meu pai, nem com minha família, mas hoje eu fico feliz de como as coisas es…')
# ('word_list', ['RT', '@jgabrieldiass:', 'eu', 'nunca', 'tive', 'uma', 'relação', 'muito', 'saudável', 'com', 'meu', 'pai,', 'nem', 'com', 'minha', 'família,', 'mas', 'hoje', 'eu', 'fico', 'feliz', 'de', 'como', 'as', 'coisas', 'es…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 3, 617069))
# ('data_tweet', 'Sun Aug 08 23:51:57 +0000 2021')
# ('nome', 'vanessa')
# ('perfil_criado', 'Sun Aug 08 23:51:57 +0000 2021')
# ('descricao_usuario', '❥ ᴅᴄ • ᴛɪᴛᴀɴs • ᴛʜᴇ ғʟᴀsʜ • ʟᴏᴛʀ • She/Her • fan account')
# ('url_usuario', 'http://startroy.tumblr.com')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 2279)
# ('seguidores', 2341)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'themyscira')
# ('tweet_full_text', 'RT @guithomazzz: a gente assistindo esquadrão suicida ontem https://t.co/cDo99Ql1pQ')
# ('word_list', ['RT', '@guithomazzz:', 'a', 'gente', 'assistindo', 'esquadrão', 'suicida', 'ontem', 'https://t.co/cDo99Ql1pQ'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 3, 937038))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', 'Bianquinha')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', 'sou eu e não tem outra')
# ('url_usuario', 'https://www.instagram.com/beneduci_?r=nametag')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 219)
# ('seguidores', 84)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @Itspedrito: o ruim de ser gostosa eh que ninguém me leva a sério')
# ('word_list', ['RT', '@Itspedrito:', 'o', 'ruim', 'de', 'ser', 'gostosa', 'eh', 'que', 'ninguém', 'me', 'leva', 'a', 'sério'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 258338))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', 'oh u babaaaau')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', 'quem gostou bate palma.\nquem não gostou, paciência.')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 154)
# ('seguidores', 52)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'na baixa da égua')
# ('tweet_full_text', 'RT @oednaldopereira: Comparação  de likes de gostei  fotos  Ednaldo Pereira https://t.co/31EUyKhr6H')
# ('word_list', ['RT', '@oednaldopereira:', 'Comparação', '', 'de', 'likes', 'de', 'gostei', '', 'fotos', '', 'Ednaldo', 'Pereira', 'https://t.co/31EUyKhr6H'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 485845))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', 'Marcia Regina')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 562)
# ('seguidores', 533)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [{'text': 'LulaLadrão', 'indices': [21, 32]}])
# ('location', 'None')
# ('tweet_full_text', 'RT @SergioAndreassa: #LulaLadrão\nDevolve nosso dinheiro cachaceiro.. https://t.co/HrbeS2V02d')
# ('word_list', ['RT', '@SergioAndreassa:', '#LulaLadrão\nDevolve', 'nosso', 'dinheiro', 'cachaceiro..', 'https://t.co/HrbeS2V02d'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 495002))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', 'Siddarta Gautama 🇮🇳')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', 'Sem medo de morrer ☸️\nNão sou Flamenguista 😡\nPrático karatê 🥋\nSkate 🛹')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 78)
# ('seguidores', 8)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Garanhuns-PE')
# ('tweet_full_text', '@simpraisa Assim espero Deus te ouça')
# ('word_list', ['@simpraisa', 'Assim', 'espero', 'Deus', 'te', 'ouça'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 502956))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', 'laurinha៹ mudou a pack!!!')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 239)
# ('seguidores', 296)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'ela (eu) dele (gabriel)')
# ('tweet_full_text', 'RT @OsFlanaticos_: agora eu tô sentindo a dor que o Flamengo causou nos outros times ultimamente')
# ('word_list', ['RT', '@OsFlanaticos_:', 'agora', 'eu', 'tô', 'sentindo', 'a', 'dor', 'que', 'o', 'Flamengo', 'causou', 'nos', 'outros', 'times', 'ultimamente'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 522003))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', '𝐊𝐚𝐡ღ || tá viajando')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', 'Kah e Amity lendo Dom Casmurro. 📚')
# ('url_usuario', 'http://Polo.xn--c6h')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 1732)
# ('seguidores', 2090)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', '「ela/ele」')
# ('tweet_full_text', 'a aury reclama que eu não tô respondendo ela SWNDO QUE A BONITA TA DANDO RT E NADA DE ME RESPONDER NA DM    EU TENH… https://t.co/cRJ0TDlpKs')
# ('word_list', ['a', 'aury', 'reclama', 'que', 'eu', 'não', 'tô', 'respondendo', 'ela', 'SWNDO', 'QUE', 'A', 'BONITA', 'TA', 'DANDO', 'RT', 'E', 'NADA', 'DE', 'ME', 'RESPONDER', 'NA', 'DM', '', '', '', 'EU', 'TENH…', 'https://t.co/cRJ0TDlpKs'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 745914))
# ('data_tweet', 'Sun Aug 08 23:51:58 +0000 2021')
# ('nome', 'Alexandre Martini')
# ('perfil_criado', 'Sun Aug 08 23:51:58 +0000 2021')
# ('descricao_usuario', '“Desgraçado do tempo em que os loucos guiam os cegos.” William Shakespeare - ‘Rei Lear’')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 888)
# ('seguidores', 421)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @AdilaDahwache3: ESTA É, A PERGUNTA DO DIA. QUANTOS  ????????? https://t.co/g8MlyNXsRt')
# ('word_list', ['RT', '@AdilaDahwache3:', 'ESTA', 'É,', 'A', 'PERGUNTA', 'DO', 'DIA.', 'QUANTOS', '', '?????????', 'https://t.co/g8MlyNXsRt'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 890294))
# ('data_tweet', 'Sun Aug 08 23:51:59 +0000 2021')
# ('nome', 'Mags')
# ('perfil_criado', 'Sun Aug 08 23:51:59 +0000 2021')
# ('descricao_usuario', 'Be the change you wish to see in the world.\nFEUC 📚')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 393)
# ('seguidores', 192)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @sigocomfe: Amor é quando você olha pra pessoa e tem a certeza de que não quer que mais ninguém ocupe aquele lugar além dela, independen…')
# ('word_list', ['RT', '@sigocomfe:', 'Amor', 'é', 'quando', 'você', 'olha', 'pra', 'pessoa', 'e', 'tem', 'a', 'certeza', 'de', 'que', 'não', 'quer', 'que', 'mais', 'ninguém', 'ocupe', 'aquele', 'lugar', 'além', 'dela,', 'independen…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 4, 960155))
# ('data_tweet', 'Sun Aug 08 23:51:59 +0000 2021')
# ('nome', '🐼 YASMIN • Privacy • Chamadas/Sexting/Packs')
# ('perfil_criado', 'Sun Aug 08 23:51:59 +0000 2021')
# ('descricao_usuario', 'Wishilist: https://wshl.st/xdriba • 27, modelo alternativa 💁🏻\u200d♀️, tatuada💀 , NSFW +18, 1,64 de alt 📐 • Direct para vendas 💌 ~ @sejaprivacy')
# ('url_usuario', 'https://www.privacy.com.br/profile/Yasmin')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 166)
# ('seguidores', 4079)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'PicPay: MiniYasmin ')
# ('tweet_full_text', 'RT @NicoFuckSex: Feliz dia dos país Daddy, vem ca receber desconto da sua menininha, alem de uns brindezinhos ♥️')
# ('word_list', ['RT', '@NicoFuckSex:', 'Feliz', 'dia', 'dos', 'país', 'Daddy,', 'vem', 'ca', 'receber', 'desconto', 'da', 'sua', 'menininha,', 'alem', 'de', 'uns', 'brindezinhos', '♥️'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 5, 95798))
# ('data_tweet', 'Sun Aug 08 23:51:59 +0000 2021')
# ('nome', 'William Oliveira')
# ('perfil_criado', 'Sun Aug 08 23:51:59 +0000 2021')
# ('descricao_usuario', 'XX·l·MMIII🐊\n18 ANOS 🐊\nCAPRICÓRNIO🐊\nPontal / SP 🔁 Goiânia🐊\n\ninsta:@owilliam_oficial')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 133)
# ('seguidores', 9)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Sertãozinho, Brasil')
# ('tweet_full_text', '@guxtalok7 @el_igor007 @Alansx011 Na copa nfa eu acho que tá  3x2 mesmo')
# ('word_list', ['@guxtalok7', '@el_igor007', '@Alansx011', 'Na', 'copa', 'nfa', 'eu', 'acho', 'que', 'tá', '', '3x2', 'mesmo'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 5, 108029))
# ('data_tweet', 'Sun Aug 08 23:51:59 +0000 2021')
# ('nome', 'duda | 9¾')
# ('perfil_criado', 'Sun Aug 08 23:51:59 +0000 2021')
# ('descricao_usuario', 'eu, t3ddy, madelyn, rory e lavinia vendo hp')
# ('url_usuario', 'https://instagram.com/seriesxsoft?utm_medium=copy_link')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 370)
# ('seguidores', 532)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @arwrudy: assistiu outerbanks e não gostou da sarah = mau caráter')
# ('word_list', ['RT', '@arwrudy:', 'assistiu', 'outerbanks', 'e', 'não', 'gostou', 'da', 'sarah', '=', 'mau', 'caráter'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 5, 145178))
# ('data_tweet', 'Sun Aug 08 23:51:59 +0000 2021')
# ('nome', 'milly in RED 🌹♥️🌹')
# ('perfil_criado', 'Sun Aug 08 23:51:59 +0000 2021')
# ('descricao_usuario', 'happy, free, confused and lonely at the same time. 🌹🌹🌹 nov. 19th')
# ('url_usuario', 'https://linktr.ee/Jamillymaia')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 221)
# ('seguidores', 205)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Ceará, Brasil')
# ('tweet_full_text', 'literalmente não consigo mais fazer uma amizade ou qualquer coisa nesse mundo sem falar dessa mulher')
# ('word_list', ['literalmente', 'não', 'consigo', 'mais', 'fazer', 'uma', 'amizade', 'ou', 'qualquer', 'coisa', 'nesse', 'mundo', 'sem', 'falar', 'dessa', 'mulher'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 5, 169590))
# ('data_tweet', 'Sun Aug 08 23:51:59 +0000 2021')
# ('nome', 'carolinne ornellas \U0001fab4')
# ('perfil_criado', 'Sun Aug 08 23:51:59 +0000 2021')
# ('descricao_usuario', 'intelectual porém barraqueira // capixaba & professora do ensino básico público // perfil apreciador de futebol, vôlei e política.')
# ('url_usuario', 'http://instagram.com/ouquerol')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 555)
# ('seguidores', 867)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Vitória, ES')
# ('tweet_full_text', '@sualvescruz Kkkkkkk né? Aqui é igual, eu vivo o Flamengo desde 89, vou me estressar com uma derrota pro internacio… https://t.co/xLf5z11zvG')
# ('word_list', ['@sualvescruz', 'Kkkkkkk', 'né?', 'Aqui', 'é', 'igual,', 'eu', 'vivo', 'o', 'Flamengo', 'desde', '89,', 'vou', 'me', 'estressar', 'com', 'uma', 'derrota', 'pro', 'internacio…', 'https://t.co/xLf5z11zvG'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 5, 878781))
# ('data_tweet', 'Sun Aug 08 23:52:00 +0000 2021')
# ('nome', 'bru!')
# ('perfil_criado', 'Sun Aug 08 23:52:00 +0000 2021')
# ('descricao_usuario', 'HEY LOUIS... i love you! | -a/ela/a')
# ('url_usuario', 'http://shinelouiis.carrd.co')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2228)
# ('seguidores', 2460)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'the future')
# ('tweet_full_text', '@fklouie traduz eu nunca te pedi nada')
# ('word_list', ['@fklouie', 'traduz', 'eu', 'nunca', 'te', 'pedi', 'nada'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 20, 52, 5, 885724))
# ('data_tweet', 'Sun Aug 08 23:52:00 +0000 2021')
# ('nome', 'Ramona Gusyeva 🏳️\u200d⚧️')
# ('perfil_criado', 'Sun Aug 08 23:52:00 +0000 2021')
# ('descricao_usuario', 'Sou uma comunicadora esportiva transgênero \nFalo sobre:\nFutebol(⚽), NHL(🏒), NBA(🏀), NFL(🏈)')
# ('url_usuario', 'https://www.youtube.com/c/RamonaGusyeva/videos')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 929)
# ('seguidores', 3519)
# ('retweets', 0)
# ...
# ('data_tweet', 'Mon Aug 09 00:01:43 +0000 2021')
# ('nome', 'ana 🎸')
# ('perfil_criado', 'Mon Aug 09 00:01:43 +0000 2021')
# ('descricao_usuario', '• melzinha • lhama • amanim •\n| fan account | \n\u2063')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 713)
# ('seguidores', 896)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'rbd&rbr•chamel•fiuk•sçk•spfc')
# ('tweet_full_text', '@hankerfuck antes tarde do q nunca du é o maior de todos')
# ('word_list', ['@hankerfuck', 'antes', 'tarde', 'do', 'q', 'nunca', 'du', 'é', 'o', 'maior', 'de', 'todos'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 50, 859641))
# ('data_tweet', 'Mon Aug 09 00:01:44 +0000 2021')
# ('nome', 'kaah')
# ('perfil_criado', 'Mon Aug 09 00:01:44 +0000 2021')
# ('descricao_usuario', '...')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 236)
# ('seguidores', 165)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'São Paulo, Brasil')
# ('tweet_full_text', 'Tão bom o jeito que o Paulo se importa cmg')
# ('word_list', ['Tão', 'bom', 'o', 'jeito', 'que', 'o', 'Paulo', 'se', 'importa', 'cmg'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 50, 867553))
# ('data_tweet', 'Mon Aug 09 00:01:44 +0000 2021')
# ('nome', 'Cellezto')
# ('perfil_criado', 'Mon Aug 09 00:01:44 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'Twitter Web App</a>')
# ('seguindo', 120)
# ('seguidores', 22)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@UrubuTT_ fechou bem o angulo!')
# ('word_list', ['@UrubuTT_', 'fechou', 'bem', 'o', 'angulo!'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 50, 874269))
# ('data_tweet', 'Mon Aug 09 00:01:44 +0000 2021')
# ('nome', 'Gabriel Hunter.')
# ('perfil_criado', 'Mon Aug 09 00:01:44 +0000 2021')
# ('descricao_usuario', '23 anos, bacharel em Direito, pós graduando em Direito e Processo Penal, gaúcho de Porto Alegre, esquerdista chato e namorando (quase casando) com uma louca aí.')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 1224)
# ('seguidores', 390)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @eduardodeconto: E todos os jogadores do Inter correndo pra abraçar o Taison. Precisava muito do gol https://t.co/d9dUcQLEE2')
# ('word_list', ['RT', '@eduardodeconto:', 'E', 'todos', 'os', 'jogadores', 'do', 'Inter', 'correndo', 'pra', 'abraçar', 'o', 'Taison.', 'Precisava', 'muito', 'do', 'gol', 'https://t.co/d9dUcQLEE2'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 50, 881419))
# ('data_tweet', 'Mon Aug 09 00:01:44 +0000 2021')
# ('nome', 'wony')
# ('perfil_criado', 'Mon Aug 09 00:01:44 +0000 2021')
# ('descricao_usuario', 'yakisoba')
# ('url_usuario', 'https://curiouscat.qa/jennieursinho')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 436)
# ('seguidores', 479)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'she/her  🐸🧡')
# ('tweet_full_text', '@junkyucantor cade')
# ('word_list', ['@junkyucantor', 'cade'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 50, 888233))
# ('data_tweet', 'Mon Aug 09 00:01:44 +0000 2021')
# ('nome', 'Gustavo Vinicius')
# ('perfil_criado', 'Mon Aug 09 00:01:44 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 172)
# ('seguidores', 273)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@elcinhojhow Claaaroooo, domingou!')
# ('word_list', ['@elcinhojhow', 'Claaaroooo,', 'domingou!'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 50, 911214))
# ('data_tweet', 'Mon Aug 09 00:01:45 +0000 2021')
# ('nome', 'Joyce almeida 🧜🏽\u200d♀️')
# ('perfil_criado', 'Mon Aug 09 00:01:45 +0000 2021')
# ('descricao_usuario', 'Teimosa, mandona e orgulhosa. •061, BR')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 183)
# ('seguidores', 128)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', '061')
# ('tweet_full_text', 'Eu não sei de onde tirei tanto sono hj')
# ('word_list', ['Eu', 'não', 'sei', 'de', 'onde', 'tirei', 'tanto', 'sono', 'hj'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 51, 81087))
# ('data_tweet', 'Mon Aug 09 00:01:45 +0000 2021')
# ('nome', 'Yaya ຊ')
# ('perfil_criado', 'Mon Aug 09 00:01:45 +0000 2021')
# ('descricao_usuario', 'apenas mais uma boiola por @laurenjauregui || KARILAຊ')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 110)
# ('seguidores', 30)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [{'text': 'COPANFA', 'indices': [74, 82]}])
# ('location', 'Hogwarts ')
# ('tweet_full_text', 'ALO NOISE????? TA PODENDO FALAR???? OI TA MUITO OCUPADO METENDO BOOYAH NA #COPANFA ??????????')
# ('word_list', ['ALO', 'NOISE?????', 'TA', 'PODENDO', 'FALAR????', 'OI', 'TA', 'MUITO', 'OCUPADO', 'METENDO', 'BOOYAH', 'NA', '#COPANFA', '??????????'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 51, 88482))
# ('data_tweet', 'Mon Aug 09 00:01:45 +0000 2021')
# ('nome', 'carol aqlas cenas')
# ('perfil_criado', 'Mon Aug 09 00:01:45 +0000 2021')
# ('descricao_usuario', 'obsession w http://lucca.xn--6ii @thayrlxp @corinthians💍 | @carolllxntj.')
# ('url_usuario', 'https://www.twitch.tv/lucca_trem')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 2633)
# ('seguidores', 2288)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'ᵈᵈᶜ')
# ('tweet_full_text', '@loud_thurzin888 OS MELHORES DO MUNDO')
# ('word_list', ['@loud_thurzin888', 'OS', 'MELHORES', 'DO', 'MUNDO'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 51, 133103))
# ('data_tweet', 'Mon Aug 09 00:01:45 +0000 2021')
# ('nome', 'maggy :))')
# ('perfil_criado', 'Mon Aug 09 00:01:45 +0000 2021')
# ('descricao_usuario', 'deixa disso ig: margaridaddsantos_')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 701)
# ('seguidores', 1445)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @mariapastilhas: quanto mais preciso dos meus amigos, menos estão presentes')
# ('word_list', ['RT', '@mariapastilhas:', 'quanto', 'mais', 'preciso', 'dos', 'meus', 'amigos,', 'menos', 'estão', 'presentes'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 52, 769200))
# ('data_tweet', 'Mon Aug 09 00:01:46 +0000 2021')
# ('nome', 'lisse')
# ('perfil_criado', 'Mon Aug 09 00:01:46 +0000 2021')
# ('descricao_usuario', 'ﾠ minari? yup ʕ·ᴥ·ʔ')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 533)
# ('seguidores', 478)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'ᵍʳᵉᵉⁿᵈᵃˡᵉ')
# ('tweet_full_text', 'RT @GirlgroupsBR: É A MAMACITA! A Hyoyeon liberou hoje o MV teaser para o seu comeback com o single "Second", que conta com a colaboração d…')
# ('word_list', ['RT', '@GirlgroupsBR:', 'É', 'A', 'MAMACITA!', 'A', 'Hyoyeon', 'liberou', 'hoje', 'o', 'MV', 'teaser', 'para', 'o', 'seu', 'comeback', 'com', 'o', 'single', '"Second",', 'que', 'conta', 'com', 'a', 'colaboração', 'd…'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 52, 779287))
# ('data_tweet', 'Mon Aug 09 00:01:46 +0000 2021')
# ('nome', 'lu¡sa. 📖: hp⁷')
# ('perfil_criado', 'Mon Aug 09 00:01:46 +0000 2021')
# ('descricao_usuario', 'soup, sex and sun salutations ㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤ{a/ela/-a}')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 1840)
# ('seguidores', 2083)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'only nourry!')
# ('tweet_full_text', '@foIksos credo, a radiação')
# ('word_list', ['@foIksos', 'credo,', 'a', 'radiação'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 52, 790309))
# ('data_tweet', 'Mon Aug 09 00:01:46 +0000 2021')
# ('nome', 'Petru')
# ('perfil_criado', 'Mon Aug 09 00:01:46 +0000 2021')
# ('descricao_usuario', 'romântico, safado, carinhoso e até fiel')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 91)
# ('seguidores', 96)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', '@eu_anttonia E pra isso que você treina compra sim')
# ('word_list', ['@eu_anttonia', 'E', 'pra', 'isso', 'que', 'você', 'treina', 'compra', 'sim'])
# ('coordinates', 'None')
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 52, 999576))
# ('data_tweet', 'Mon Aug 09 00:01:47 +0000 2021')
# ('nome', 'Gabs🦋')
# ('perfil_criado', 'Mon Aug 09 00:01:47 +0000 2021')
# ('descricao_usuario', 'oi, o que vc quer por aqui?')
# ('url_usuario', 'http://vsco.co/gabbsxz')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 156)
# ('seguidores', 162)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'no seu coração')
# ('tweet_full_text', 'RT @heyaigu: dói demais abrir mão de alguém porque você sente, no íntimo, que ela não está na mesma frequência afetiva ou amorosa que você.')
# ('word_list', ['RT', '@heyaigu:', 'dói', 'demais', 'abrir', 'mão', 'de', 'alguém', 'porque', 'você', 'sente,', 'no', 'íntimo,', 'que', 'ela', 'não', 'está', 'na', 'mesma', 'frequência', 'afetiva', 'ou', 'amorosa', 'que', 'você.'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 54, 41814))
# ('data_tweet', 'Mon Aug 09 00:01:48 +0000 2021')
# ('nome', 'jubs🧃')
# ('perfil_criado', 'Mon Aug 09 00:01:48 +0000 2021')
# ('descricao_usuario', 'sobrevivente')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 215)
# ('seguidores', 177)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'tava conversando c um menino e ele mandou “😫💞” ?????????')
# ('word_list', ['tava', 'conversando', 'c', 'um', 'menino', 'e', 'ele', 'mandou', '“😫💞”', '?????????'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 54, 365354))
# ('data_tweet', 'Mon Aug 09 00:01:48 +0000 2021')
# ('nome', 'Letícia.morais')
# ('perfil_criado', 'Mon Aug 09 00:01:48 +0000 2021')
# ('descricao_usuario', 'None')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 63)
# ('seguidores', 5)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'None')
# ('tweet_full_text', 'RT @natjaguarlovato: Quem não dá rt nos pulinhos da brait vai ter 10 anos de azar hein \n\nOBRIGADA BRAIT \n\n https://t.co/jOqWMJvQ5S')
# ('word_list', ['RT', '@natjaguarlovato:', 'Quem', 'não', 'dá', 'rt', 'nos', 'pulinhos', 'da', 'brait', 'vai', 'ter', '10', 'anos', 'de', 'azar', 'hein', '\n\nOBRIGADA', 'BRAIT', '\n\n', 'https://t.co/jOqWMJvQ5S'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 54, 373311))
# ('data_tweet', 'Mon Aug 09 00:01:48 +0000 2021')
# ('nome', 'lavis 🐉')
# ('perfil_criado', 'Mon Aug 09 00:01:48 +0000 2021')
# ('descricao_usuario', 'amante do pagode e do @Flamengo')
# ('url_usuario', 'None')
# ('user_verificado', False)
# ('source', 'ofollow">Twitter for Android</a>')
# ('seguindo', 892)
# ('seguidores', 1469)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'O27  • 19y ')
# ('tweet_full_text', 'Vontade de um lanche gourmet 😩')
# ('word_list', ['Vontade', 'de', 'um', 'lanche', 'gourmet', '😩'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 54, 380096))
# ('data_tweet', 'Mon Aug 09 00:01:48 +0000 2021')
# ('nome', 'stephany 🦋⚡️')
# ('perfil_criado', 'Mon Aug 09 00:01:48 +0000 2021')
# ('descricao_usuario', 'Bela, arretada e d’Oyá ⚡')
# ('url_usuario', 'https://www.instagram.com/p/CBRNjn4J3K8/?igshid=1kj1w4txrcjhc')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 378)
# ('seguidores', 1297)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Rio de Janeiro')
# ('tweet_full_text', '@Jr7Naval te amo, amor ❤️❤️❤️❤️❤️')
# ('word_list', ['@Jr7Naval', 'te', 'amo,', 'amor', '❤️❤️❤️❤️❤️'])
# ('coordinates', 'None')
#
# ('@timestamp', datetime.datetime(2021, 8, 8, 21, 1, 54, 593506))
# ('data_tweet', 'Mon Aug 09 00:01:48 +0000 2021')
# ('nome', 'PEDRO')
# ('perfil_criado', 'Mon Aug 09 00:01:48 +0000 2021')
# ('descricao_usuario', 'As vezes o segredo está em sonhar até que o mundo se encha de cores. 💖💍@oyanngomes')
# ('url_usuario', 'http://Instagram.com/arrobaperdo')
# ('user_verificado', False)
# ('source', 'follow">Twitter for iPhone</a>')
# ('seguindo', 1674)
# ('seguidores', 2700)
# ('retweets', 0)
# ('likes', 0)
# ('hashtags', [])
# ('location', 'Niterói, Brasil')
# ('tweet_full_text', 'RT @uchizsa: a mulher bebendo no canudo da gaga meu deus kkkkkkk https://t.co/9RhSU73wN4')
# ('word_list', ['RT', '@uchizsa:', 'a', 'mulher', 'bebendo', 'no', 'canudo', 'da', 'gaga', 'meu', 'deus', 'kkkkkkk', 'https://t.co/9RhSU73wN4'])
# ('coordinates', 'None')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3572/1956379143.py in <module>
#     106     stream = Stream(auth, listener)
#     107
# --> 108     stream.sample(languages=['pt'])
#     109
#     110     # search twitter for "congress" keyword
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in sample(self, is_async, languages, stall_warnings)
#     447         if stall_warnings:
#     448             self.session.params['stall_warnings'] = 'true'
# --> 449         self._start(is_async)
#     450
#     451     def filter(self, follow=None, track=None, is_async=False, locations=None,
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# /usr/lib/python3/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# ~/.local/lib/python3.8/site-packages/tweepy/streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# /tmp/ipykernel_3572/1956379143.py in on_data(self, data)
#      24         if coord is not None:
#      25             coord = dict_data["coordinates"]
# ---> 26             lan = dict_data["coordinates"][0]
#      27             lat = dict_data["coordinates"][1]
#      28         else:
#
# KeyError: 0
